# %% [markdown]
# <a href="https://colab.research.google.com/github/Karsuman4298/Deep-learning/blob/main/PyTorch_Autograd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
x=torch.tensor(3,requires_grad=True,dtype=torch.float32)

# %%
y=x**2

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %%
x=torch.tensor(3,requires_grad=True,dtype=torch.float32)
y=x**2
z=torch.sin(y)

# %%
x,y,z
# Out:
# (tensor(3., requires_grad=True),
#  tensor(9., grad_fn=<PowBackward0>),
#  tensor(0.4121, grad_fn=<SinBackward0>))

# %%
z.backward()

# %%
z
# Out:
# tensor(0.4121, grad_fn=<SinBackward0>)

# %%
x.grad
# Out:
# tensor(-5.4668)

# %%
x=torch.tensor(6.7,dtype=torch.float32)
y=torch.tensor(0,dtype=torch.float32)
w=torch.tensor(1,requires_grad=True,dtype=torch.float32)
b=torch.tensor(0,requires_grad=True,dtype=torch.float32)

# %%
z= w*x+b
y_pred=torch.sigmoid(z)
loss=torch.nn.functional.binary_cross_entropy(y_pred,y)
loss.backward()

# %%
y_pred,z
w.grad.zero_,b.grad.zero_
# Out:
# (<function Tensor.zero_>, <function Tensor.zero_>)

# %%
w.grad,b.grad
# Out:
# (tensor(6.6918), tensor(0.9988))

# %% [markdown]
# # Clearing Grad

# %%
w.grad.zero_,b.grad.zero_
# Out:
# (<function Tensor.zero_>, <function Tensor.zero_>)

# %%
x=torch.tensor(6.7,dtype=torch.float32)

with torch.no_grad():# cannot backpropagate if we use this function
  y= x ** 2
